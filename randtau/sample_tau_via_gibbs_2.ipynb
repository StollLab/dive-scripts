# %%
# %load_ext autoreload
# %autoreload 2

import pymc3 as pm
import numpy as np
import math as m
import matplotlib.pyplot as plt
import dive 
import deerlab as dl

# %%
loaded_data = np.genfromtxt("../../data/2g_Pid-3223_Sid-36787.dat", skip_header = 1, delimiter = ',')
t = loaded_data[:,0]
Vexp = loaded_data[:,1]

plt.plot(t, Vexp)
plt.xlabel('t (µs)')
plt.ylabel('V')
# Out:
# Text(0, 0.5, 'V')

# %% [markdown]
# # NUTS: k, V0, lambda, sigma; Gibbs: P, delta

# %%
pars = {"method": 'regularization', "r": np.linspace(2,6,200)}
model = dive.model(t, Vexp, pars)

# %%
MCMCparameters = {"draws": 5000,"tune": 1000, "chains": 4, 'cores': 4}
trace = dive.sample(model,MCMCparameters)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >SamplePfromV: [P]
# >randDelta: [delta]
# >NUTS: [k, V0, lamb, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='24000' class='' max='24000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [24000/24000 23:34<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 1433 seconds.
# WARNING (aesara.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# The number of effective samples is smaller than 10% for some parameters.

# %%
dive.summary(trace, model, Pid = 3223)
# Out:
#            mean        sd    hdi_3%    hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# k         0.046     0.003     0.039      0.052      0.000    0.000    6142.0
# λ         0.512     0.005     0.502      0.521      0.000    0.000    4072.0
# V₀        0.987     0.008     0.973      1.004      0.000    0.000    4375.0
# σ         0.020     0.001     0.019      0.022      0.000    0.000    8172.0
# δ      7991.494  3572.870  2032.926  14391.776    143.518  101.530     575.0
# lg(α)     0.236     0.100     0.042      0.415      0.004    0.003     594.0
#
#        ess_tail  r_hat
# k        7946.0   1.00
# λ        7196.0   1.00
# V₀       7157.0   1.00
# σ        7999.0   1.00
# δ         990.0   1.01
# lg(α)    1030.0   1.01

# %% [markdown]
# # NUTS: k, V0, lambda; Gibbs: P, tau, delta

# %%
pars = {"method": 'regularization_taubased', "r": np.linspace(2,6,200)}
model = dive.model(t, Vexp, pars)

# %%
MCMCparameters = {"draws": 5000,"tune": 1000, "chains": 4, 'cores': 4}
trace_tau = dive.sample(model,MCMCparameters)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >SamplePfromV: [P]
# >randTau: [tau]
# >randDelta: [delta]
# >NUTS: [k, V0, lamb]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='24000' class='' max='24000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [24000/24000 20:52<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 1273 seconds.
# WARNING (aesara.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# The acceptance probability does not match the target. It is 0.9027145843580467, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8808006723260895, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 10% for some parameters.

# %%
dive.summary(trace_tau, model, Pid = 3223)
# Out:
#            mean        sd    hdi_3%    hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# k         0.046     0.004     0.040      0.053      0.000    0.000    4006.0
# λ         0.512     0.005     0.502      0.521      0.000    0.000    2840.0
# V₀        0.987     0.008     0.973      1.003      0.000    0.000    3128.0
# σ         0.020     0.001     0.019      0.022      0.000    0.000   17671.0
# δ      8171.352  3681.641  1993.026  14609.776    146.310  103.504     589.0
# lg(α)     0.239     0.100     0.047      0.423      0.004    0.003     605.0
#
#        ess_tail  r_hat
# k        4710.0    1.0
# λ        5042.0    1.0
# V₀       5124.0    1.0
# σ       19222.0    1.0
# δ        1045.0    1.0
# lg(α)    1198.0    1.0
